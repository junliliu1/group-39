# %% [markdown]
# # Wine Quality Predictor Report

# %% [markdown]
# ## Summary

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Data

# %% [markdown]
# ### Analysis

# %% [markdown]
# ## Results & Discussion

# %% [markdown]
# ## References
